# %%
import pandas as pd

# %%
data = pd.read_csv("./data/nfl_mahomes_era_games.csv")

# %%
data.columns
# Out:
# Index(['season', 'game_id', 'game_type', 'week', 'home_team', 'away_team',
#        'home_score', 'away_score', 'game_outcome', 'score_diff'],
#       dtype='object')

# %%
cv = data[['home_team', 'season']].value_counts().to_dict()

{k:v for k, v in sorted(cv.items())}
# Out:
# {('ARI', 2018): 8,
#  ('ARI', 2019): 8,
#  ('ARI', 2020): 8,
#  ('ARI', 2021): 8,
#  ('ARI', 2022): 9,
#  ('ARI', 2023): 8,
#  ('ATL', 2018): 8,
#  ('ATL', 2019): 8,
#  ('ATL', 2020): 8,
#  ('ATL', 2021): 8,
#  ('ATL', 2022): 9,
#  ('ATL', 2023): 8,
#  ('BAL', 2018): 9,
#  ('BAL', 2019): 9,
#  ('BAL', 2020): 8,
#  ('BAL', 2021): 9,
#  ('BAL', 2022): 8,
#  ('BAL', 2023): 11,
#  ('BUF', 2018): 8,
#  ('BUF', 2019): 8,
#  ('BUF', 2020): 10,
#  ('BUF', 2021): 10,
#  ('BUF', 2022): 10,
#  ('BUF', 2023): 11,
#  ('CAR', 2018): 8,
#  ('CAR', 2019): 8,
#  ('CAR', 2020): 8,
#  ('CAR', 2021): 8,
#  ('CAR', 2022): 9,
#  ('CAR', 2023): 8,
#  ('CHI', 2018): 9,
#  ('CHI', 2019): 8,
#  ('CHI', 2020): 8,
#  ('CHI', 2021): 8,
#  ('CHI', 2022): 9,
#  ('CHI', 2023): 8,
#  ('CIN', 2018): 8,
#  ('CIN', 2019): 8,
#  ('CIN', 2020): 8,
#  ('CIN', 2021): 11,
#  ('CIN', 2022): 8,
#  ('CIN', 2023): 9,
#  ('CLE', 2018): 8,
#  ('CLE', 2019): 8,
#  ('CLE', 2020): 8,
#  ('CLE', 2021): 9,
#  ('CLE', 2022): 8,
#  ('CLE', 2023): 9,
#  ('DAL', 2018): 9,
#  ('DAL', 2019): 8,
#  ('DAL', 2020): 8,
#  ('DAL', 2021): 9,
#  ('DAL', 2022): 9,
#  ('DAL', 2023): 9,
#  ('DEN', 2018): 8,
#  ('DEN', 2019): 8,
#  ('DEN', 2020): 8,
#  ('DEN', 2021): 9,
#  ('DEN', 2022): 8,
#  ('DEN', 2023): 9,
#  ('DET', 2018): 8,
#  ('DET', 2019): 8,
#  ('DET', 2020): 8,
#  ('DET', 2021): 8,
#  ('DET', 2022): 9,
#  ('DET', 2023): 10,
#  ('GB', 2018): 8,
#  ('GB', 2019): 9,
#  ('GB', 2020): 10,
#  ('GB', 2021): 9,
#  ('GB', 2022): 9,
#  ('GB', 2023): 8,
#  ('HOU', 2018): 9,
#  ('HOU', 2019): 9,
#  ('HOU', 2020): 8,
#  ('HOU', 2021): 9,
#  ('HOU', 2022): 8,
#  ('HOU', 2023): 10,
#  ('IND', 2018): 8,
#  ('IND', 2019): 8,
#  ('IND', 2020): 8,
#  ('IND', 2021): 9,
#  ('IND', 2022): 8,
#  ('IND', 2023): 9,
#  ('JAX', 2018): 8,
#  ('JAX', 2019): 8,
#  ('JAX', 2020): 8,
#  ('JAX', 2021): 9,
#  ('JAX', 2022): 9,
#  ('JAX', 2023): 9,
#  ('KC', 2018): 10,
#  ('KC', 2019): 11,
#  ('KC', 2020): 10,
#  ('KC', 2021): 12,
#  ('KC', 2022): 10,
#  ('KC', 2023): 11,
#  ('LA', 2018): 10,
#  ('LA', 2019): 8,
#  ('LA', 2020): 8,
#  ('LA', 2021): 10,
#  ('LA', 2022): 9,
#  ('LA', 2023): 8,
#  ('LAC', 2018): 8,
#  ('LAC', 2019): 8,
#  ('LAC', 2020): 8,
#  ('LAC', 2021): 9,
#  ('LAC', 2022): 8,
#  ('LAC', 2023): 9,
#  ('LV', 2020): 8,
#  ('LV', 2021): 9,
#  ('LV', 2022): 8,
#  ('LV', 2023): 9,
#  ('MIA', 2018): 8,
#  ('MIA', 2019): 8,
#  ('MIA', 2020): 8,
#  ('MIA', 2021): 9,
#  ('MIA', 2022): 8,
#  ('MIA', 2023): 9,
#  ('MIN', 2018): 8,
#  ('MIN', 2019): 8,
#  ('MIN', 2020): 8,
#  ('MIN', 2021): 8,
#  ('MIN', 2022): 10,
#  ('MIN', 2023): 8,
#  ('NE', 2018): 9,
#  ('NE', 2019): 9,
#  ('NE', 2020): 8,
#  ('NE', 2021): 9,
#  ('NE', 2022): 8,
#  ('NE', 2023): 9,
#  ('NO', 2018): 10,
#  ('NO', 2019): 9,
#  ('NO', 2020): 10,
#  ('NO', 2021): 8,
#  ('NO', 2022): 9,
#  ('NO', 2023): 8,
#  ('NYG', 2018): 8,
#  ('NYG', 2019): 8,
#  ('NYG', 2020): 8,
#  ('NYG', 2021): 8,
#  ('NYG', 2022): 9,
#  ('NYG', 2023): 8,
#  ('NYJ', 2018): 8,
#  ('NYJ', 2019): 8,
#  ('NYJ', 2020): 8,
#  ('NYJ', 2021): 9,
#  ('NYJ', 2022): 8,
#  ('NYJ', 2023): 9,
#  ('OAK', 2018): 8,
#  ('OAK', 2019): 8,
#  ('PHI', 2018): 8,
#  ('PHI', 2019): 9,
#  ('PHI', 2020): 8,
#  ('PHI', 2021): 8,
#  ('PHI', 2022): 12,
#  ('PHI', 2023): 8,
#  ('PIT', 2018): 8,
#  ('PIT', 2019): 8,
#  ('PIT', 2020): 9,
#  ('PIT', 2021): 9,
#  ('PIT', 2022): 8,
#  ('PIT', 2023): 9,
#  ('SEA', 2018): 8,
#  ('SEA', 2019): 8,
#  ('SEA', 2020): 9,
#  ('SEA', 2021): 8,
#  ('SEA', 2022): 9,
#  ('SEA', 2023): 8,
#  ('SF', 2018): 8,
#  ('SF', 2019): 10,
#  ('SF', 2020): 8,
#  ('SF', 2021): 8,
#  ('SF', 2022): 11,
#  ('SF', 2023): 10,
#  ('TB', 2018): 8,
#  ('TB', 2019): 8,
#  ('TB', 2020): 9,
#  ('TB', 2021): 10,
#  ('TB', 2022): 10,
#  ('TB', 2023): 9,
#  ('TEN', 2018): 8,
#  ('TEN', 2019): 8,
#  ('TEN', 2020): 9,
#  ('TEN', 2021): 10,
#  ('TEN', 2022): 8,
#  ('TEN', 2023): 9,
#  ('WAS', 2018): 8,
#  ('WAS', 2019): 8,
#  ('WAS', 2020): 9,
#  ('WAS', 2021): 8,
#  ('WAS', 2022): 9,
#  ('WAS', 2023): 8}

# %%
import json
names = json.load(open("./data/names.json", "r"))

# %%
data["home_team"].map(names)
# Out:
# 0       Philadelphia Eagles
# 1          Baltimore Ravens
# 2          Cleveland Browns
# 3        Indianapolis Colts
# 4            Miami Dolphins
#                ...
# 1652          Detroit Lions
# 1653          Buffalo Bills
# 1654       Baltimore Ravens
# 1655    San Francisco 49ers
# 1656     Kansas City Chiefs
# Name: home_team, Length: 1657, dtype: object

# %%
data['game_outcome'].unique()
# Out:
# array([1. , 0.5, 0. ])

# %%
from utils import process_nfl_dataset

# %%
season=2018
dataset = pd.read_csv("./data/nfl_mahomes_era_games.csv")
preference_data, matchday_dict, unique_matches, team_dict, team_identifier, gold_rankings = process_nfl_dataset(dataset, season)

# %%
preference_data
# Out:
# [('PHI', 'ATL', 'W'),
#  ('BAL', 'BUF', 'W'),
#  ('CLE', 'PIT', 'D'),
#  ('CIN', 'IND', 'W'),
#  ('MIA', 'TEN', 'W'),
#  ('MIN', 'SF', 'W'),
#  ('NE', 'HOU', 'W'),
#  ('TB', 'NO', 'W'),
#  ('JAX', 'NYG', 'W'),
#  ('KC', 'LAC', 'W'),
#  ('WAS', 'ARI', 'W'),
#  ('CAR', 'DAL', 'W'),
#  ('DEN', 'SEA', 'W'),
#  ('GB', 'CHI', 'W'),
#  ('NYJ', 'DET', 'W'),
#  ('LA', 'OAK', 'W'),
#  ('CIN', 'BAL', 'W'),
#  ('ATL', 'CAR', 'W'),
#  ('LAC', 'BUF', 'W'),
#  ('GB', 'MIN', 'D'),
#  ('NO', 'CLE', 'W'),
#  ('MIA', 'NYJ', 'W'),
#  ('KC', 'PIT', 'W'),
#  ('TB', 'PHI', 'W'),
#  ('TEN', 'HOU', 'W'),
#  ('IND', 'WAS', 'W'),
#  ('LA', 'ARI', 'W'),
#  ('SF', 'DET', 'W'),
#  ('DEN', 'OAK', 'W'),
#  ('JAX', 'NE', 'W'),
#  ('DAL', 'NYG', 'W'),
#  ('CHI', 'SEA', 'W'),
#  ('CLE', 'NYJ', 'W'),
#  ('NO', 'ATL', 'W'),
#  ('BAL', 'DEN', 'W'),
#  ('CAR', 'CIN', 'W'),
#  ('NYG', 'HOU', 'W'),
#  ('TEN', 'JAX', 'W'),
#  ('KC', 'SF', 'W'),
#  ('MIA', 'OAK', 'W'),
#  ('BUF', 'MIN', 'W'),
#  ('PHI', 'IND', 'W'),
#  ('WAS', 'GB', 'W'),
#  ('LA', 'LAC', 'W'),
#  ('CHI', 'ARI', 'W'),
#  ('SEA', 'DAL', 'W'),
#  ('DET', 'NE', 'W'),
#  ('PIT', 'TB', 'W'),
#  ('LA', 'MIN', 'W'),
#  ('CIN', 'ATL', 'W'),
#  ('CHI', 'TB', 'W'),
#  ('DAL', 'DET', 'W'),
#  ('GB', 'BUF', 'W'),
#  ('HOU', 'IND', 'W'),
#  ('JAX', 'NYJ', 'W'),
#  ('NE', 'MIA', 'W'),
#  ('TEN', 'PHI', 'W'),
#  ('SEA', 'ARI', 'W'),
#  ('OAK', 'CLE', 'W'),
#  ('LAC', 'SF', 'W'),
#  ('NO', 'NYG', 'W'),
#  ('BAL', 'PIT', 'W'),
#  ('KC', 'DEN', 'W'),
#  ('NE', 'IND', 'W'),
#  ('BUF', 'TEN', 'W'),
#  ('CAR', 'NYG', 'W'),
#  ('CIN', 'MIA', 'W'),
#  ('CLE', 'BAL', 'W'),
#  ('DET', 'GB', 'W'),
#  ('KC', 'JAX', 'W'),
#  ('NYJ', 'DEN', 'W'),
#  ('PIT', 'ATL', 'W'),
#  ('LAC', 'OAK', 'W'),
#  ('MIN', 'PHI', 'W'),
#  ('LA', 'SEA', 'W'),
#  ('ARI', 'SF', 'W'),
#  ('HOU', 'DAL', 'W'),
#  ('NO', 'WAS', 'W'),
#  ('PHI', 'NYG', 'W'),
#  ('ATL', 'TB', 'W'),
#  ('PIT', 'CIN', 'W'),
#  ('LAC', 'CLE', 'W'),
#  ('HOU', 'BUF', 'W'),
#  ('MIA', 'CHI', 'W'),
#  ('MIN', 'ARI', 'W'),
#  ('NYJ', 'IND', 'W'),
#  ('SEA', 'OAK', 'W'),
#  ('WAS', 'CAR', 'W'),
#  ('LA', 'DEN', 'W'),
#  ('DAL', 'JAX', 'W'),
#  ('BAL', 'TEN', 'W'),
#  ('NE', 'KC', 'W'),
#  ('GB', 'SF', 'W'),
#  ('DEN', 'ARI', 'W'),
#  ('NE', 'CHI', 'W'),
#  ('IND', 'BUF', 'W'),
#  ('HOU', 'JAX', 'W'),
#  ('DET', 'MIA', 'W'),
#  ('MIN', 'NYJ', 'W'),
#  ('CAR', 'PHI', 'W'),
#  ('TB', 'CLE', 'W'),
#  ('NO', 'BAL', 'W'),
#  ('LA', 'SF', 'W'),
#  ('WAS', 'DAL', 'W'),
#  ('KC', 'CIN', 'W'),
#  ('LAC', 'TEN', 'W'),
#  ('ATL', 'NYG', 'W'),
#  ('HOU', 'MIA', 'W'),
#  ('CAR', 'BAL', 'W'),
#  ('CHI', 'NYJ', 'W'),
#  ('CIN', 'TB', 'W'),
#  ('SEA', 'DET', 'W'),
#  ('KC', 'DEN', 'W'),
#  ('WAS', 'NYG', 'W'),
#  ('PIT', 'CLE', 'W'),
#  ('IND', 'OAK', 'W'),
#  ('ARI', 'SF', 'W'),
#  ('LA', 'GB', 'W'),
#  ('NO', 'MIN', 'W'),
#  ('PHI', 'JAX', 'W'),
#  ('NE', 'BUF', 'W'),
#  ('SF', 'OAK', 'W'),
#  ('PIT', 'BAL', 'W'),
#  ('CHI', 'BUF', 'W'),
#  ('CAR', 'TB', 'W'),
#  ('KC', 'CLE', 'W'),
#  ('MIA', 'NYJ', 'W'),
#  ('MIN', 'DET', 'W'),
#  ('ATL', 'WAS', 'W'),
#  ('HOU', 'DEN', 'W'),
#  ('LAC', 'SEA', 'W'),
#  ('NO', 'LA', 'W'),
#  ('NE', 'GB', 'W'),
#  ('TEN', 'DAL', 'W'),
#  ('PIT', 'CAR', 'W'),
#  ('CHI', 'DET', 'W'),
#  ('NO', 'CIN', 'W'),
#  ('CLE', 'ATL', 'W'),
#  ('IND', 'JAX', 'W'),
#  ('KC', 'ARI', 'W'),
#  ('BUF', 'NYJ', 'W'),
#  ('WAS', 'TB', 'W'),
#  ('TEN', 'NE', 'W'),
#  ('LAC', 'OAK', 'W'),
#  ('GB', 'MIA', 'W'),
#  ('LA', 'SEA', 'W'),
#  ('DAL', 'PHI', 'W'),
#  ('NYG', 'SF', 'W'),
#  ('SEA', 'GB', 'W'),
#  ('DAL', 'ATL', 'W'),
#  ('BAL', 'CIN', 'W'),
#  ('DET', 'CAR', 'W'),
#  ('IND', 'TEN', 'W'),
#  ('PIT', 'JAX', 'W'),
#  ('NYG', 'TB', 'W'),
#  ('HOU', 'WAS', 'W'),
#  ('OAK', 'ARI', 'W'),
#  ('DEN', 'LAC', 'W'),
#  ('NO', 'PHI', 'W'),
#  ('CHI', 'MIN', 'W'),
#  ('LA', 'KC', 'W'),
#  ('CHI', 'DET', 'W'),
#  ('DAL', 'WAS', 'W'),
#  ('NO', 'ATL', 'W'),
#  ('BAL', 'OAK', 'W'),
#  ('BUF', 'JAX', 'W'),
#  ('SEA', 'CAR', 'W'),
#  ('CLE', 'CIN', 'W'),
#  ('NE', 'NYJ', 'W'),
#  ('PHI', 'NYG', 'W'),
#  ('TB', 'SF', 'W'),
#  ('LAC', 'ARI', 'W'),
#  ('DEN', 'PIT', 'W'),
#  ('IND', 'MIA', 'W'),
#  ('MIN', 'GB', 'W'),
#  ('HOU', 'TEN', 'W'),
#  ('DAL', 'NO', 'W'),
#  ('BAL', 'ATL', 'W'),
#  ('DEN', 'CIN', 'W'),
#  ('LA', 'DET', 'W'),
#  ('ARI', 'GB', 'W'),
#  ('HOU', 'CLE', 'W'),
#  ('JAX', 'IND', 'W'),
#  ('MIA', 'BUF', 'W'),
#  ('NYG', 'CHI', 'W'),
#  ('TB', 'CAR', 'W'),
#  ('KC', 'OAK', 'W'),
#  ('TEN', 'NYJ', 'W'),
#  ('NE', 'MIN', 'W'),
#  ('SEA', 'SF', 'W'),
#  ('LAC', 'PIT', 'W'),
#  ('PHI', 'WAS', 'W'),
#  ('TEN', 'JAX', 'W'),
#  ('NYJ', 'BUF', 'W'),
#  ('CLE', 'CAR', 'W'),
#  ('GB', 'ATL', 'W'),
#  ('IND', 'HOU', 'W'),
#  ('KC', 'BAL', 'W'),
#  ('MIA', 'NE', 'W'),
#  ('NO', 'TB', 'W'),
#  ('NYG', 'WAS', 'W'),
#  ('LAC', 'CIN', 'W'),
#  ('SF', 'DEN', 'W'),
#  ('DET', 'ARI', 'W'),
#  ('DAL', 'PHI', 'W'),
#  ('OAK', 'PIT', 'W'),
#  ('CHI', 'LA', 'W'),
#  ('SEA', 'MIN', 'W'),
#  ('LAC', 'KC', 'W'),
#  ('HOU', 'NYJ', 'W'),
#  ('CLE', 'DEN', 'W'),
#  ('ATL', 'ARI', 'W'),
#  ('BAL', 'TB', 'W'),
#  ('BUF', 'DET', 'W'),
#  ('CHI', 'GB', 'W'),
#  ('CIN', 'OAK', 'W'),
#  ('IND', 'DAL', 'W'),
#  ('WAS', 'JAX', 'W'),
#  ('MIN', 'MIA', 'W'),
#  ('TEN', 'NYG', 'W'),
#  ('SF', 'SEA', 'W'),
#  ('PIT', 'NE', 'W'),
#  ('PHI', 'LA', 'W'),
#  ('NO', 'CAR', 'W'),
#  ('TEN', 'WAS', 'W'),
#  ('BAL', 'LAC', 'W'),
#  ('ATL', 'CAR', 'W'),
#  ('CLE', 'CIN', 'W'),
#  ('DAL', 'TB', 'W'),
#  ('MIN', 'DET', 'W'),
#  ('IND', 'NYG', 'W'),
#  ('JAX', 'MIA', 'W'),
#  ('NE', 'BUF', 'W'),
#  ('GB', 'NYJ', 'W'),
#  ('PHI', 'HOU', 'W'),
#  ('LA', 'ARI', 'W'),
#  ('CHI', 'SF', 'W'),
#  ('NO', 'PIT', 'W'),
#  ('SEA', 'KC', 'W'),
#  ('OAK', 'DEN', 'W'),
#  ('BUF', 'MIA', 'W'),
#  ('DET', 'GB', 'W'),
#  ('HOU', 'JAX', 'W'),
#  ('NE', 'NYJ', 'W'),
#  ('CAR', 'NO', 'W'),
#  ('DAL', 'NYG', 'W'),
#  ('ATL', 'TB', 'W'),
#  ('BAL', 'CLE', 'W'),
#  ('LAC', 'DEN', 'W'),
#  ('KC', 'OAK', 'W'),
#  ('LA', 'SF', 'W'),
#  ('CHI', 'MIN', 'W'),
#  ('PIT', 'CIN', 'W'),
#  ('SEA', 'ARI', 'W'),
#  ('PHI', 'WAS', 'W'),
#  ('IND', 'TEN', 'W'),
#  ('IND', 'HOU', 'W'),
#  ('DAL', 'SEA', 'W'),
#  ('LAC', 'BAL', 'W'),
#  ('PHI', 'CHI', 'W'),
#  ('KC', 'IND', 'W'),
#  ('LA', 'DAL', 'W'),
#  ('NE', 'LAC', 'W'),
#  ('NO', 'PHI', 'W'),
#  ('LA', 'NO', 'W'),
#  ('NE', 'KC', 'W'),
#  ('NE', 'LA', 'W')]
